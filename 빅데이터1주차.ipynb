# %%
import pandas as pd

# %%
df = pd.read_csv("baseball.csv")

# %%
df
# Out:
#     Unnamed: 0  순위    선수명   팀명     타율  경기   타석   타수  득점
# 0            0   1  페르난데스   두산  0.365  96  447  392  72
# 1            1   2    손아섭   롯데  0.350  90  395  343  67
# 2            2   3    이정후   키움  0.347  97  428  380  64
# 3            3   4    김현수   LG  0.346  97  427  384  70
# 4            4   5    로하스   KT  0.340  93  415  376  77
# 5            5   6    최형우  KIA  0.333  90  384  330  59
# 6            6   7    오재일   두산  0.331  79  336  305  41
# 7            7   7    이명기   NC  0.331  86  339  305  54
# 8            8   9    박민우   NC  0.325  74  310  277  48
# 9            9  10    나성범   NC  0.324  87  402  358  80
# 10          10  11    김상수   삼성  0.320  76  322  272  48
# 11          11  12     정훈   롯데  0.319  63  290  251  51
# 12          12  13    박해민   삼성  0.315  84  327  305  50
# 13          13  14    강백호   KT  0.313  78  343  300  56
# 14          14  15    정수빈   두산  0.312  93  364  327  56
# 15          15  16    구자욱   삼성  0.311  72  312  273  39
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '순위', '선수명', '팀명', '타율', '경기', '타석', '타수', '득점'], dtype='object')

# %%
df["팀명"] == '두산'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: 팀명, dtype: bool

# %%
df[["선수명"]]
# Out:
#       선수명
# 0   페르난데스
# 1     손아섭
# 2     이정후
# 3     김현수
# 4     로하스
# 5     최형우
# 6     오재일
# 7     이명기
# 8     박민우
# 9     나성범
# 10    김상수
# 11     정훈
# 12    박해민
# 13    강백호
# 14    정수빈
# 15    구자욱
# 16    조용호
# 17    배정대
# 18    양의지
# 19    마차도
# 20     터커
# 21    최주환
# 22    박건우
# 23    김재호
# 24    라모스
# 25    황재균
# 26    이대호
# 27    나지완
# 28    김하성
# 29    장성우

# %%
df[['선수명','팀명','타율']]
# Out:
#       선수명   팀명     타율
# 0   페르난데스   두산  0.365
# 1     손아섭   롯데  0.350
# 2     이정후   키움  0.347
# 3     김현수   LG  0.346
# 4     로하스   KT  0.340
# 5     최형우  KIA  0.333
# 6     오재일   두산  0.331
# 7     이명기   NC  0.331
# 8     박민우   NC  0.325
# 9     나성범   NC  0.324
# 10    김상수   삼성  0.320
# 11     정훈   롯데  0.319
# 12    박해민   삼성  0.315
# 13    강백호   KT  0.313
# 14    정수빈   두산  0.312
# 15    구자욱   삼성  0.311
# 16    조용호   KT  0.310
# 17    배정대   KT  0.310
# 18    양의지   NC  0.309
# 19    마차도   롯데  0.308
# 20     터커  KIA  0.303
# 21    최주환   두산  0.301
# 22    박건우   두산  0.301
# 23    김재호   두산  0.298
# 24    라모스   LG  0.298
# 25    황재균   KT  0.294
# 26    이대호   롯데  0.293
# 27    나지완  KIA  0.292
# 28    김하성   키움  0.292
# 29    장성우   KT  0.289

# %%
df[(df['팀명'] == '두산') & (df['타율'] > 0.3)]
# Out:
#     Unnamed: 0  순위    선수명  팀명     타율  경기   타석   타수  득점
# 0            0   1  페르난데스  두산  0.365  96  447  392  72
# 6            6   7    오재일  두산  0.331  79  336  305  41
# 14          14  15    정수빈  두산  0.312  93  364  327  56
# 21          21  22    최주환  두산  0.301  94  385  345  46
# 22          22  23    박건우  두산  0.301  89  387  342  75

# %%
df[(df['팀명'] == '두산') & (df['타율'] > 0.3)].count()
# Out:
# Unnamed: 0    5
# 순위            5
# 선수명           5
# 팀명            5
# 타율            5
# 경기            5
# 타석            5
# 타수            5
# 득점            5
# dtype: int64

# %%
df[(df['팀명'] == '두산') | (df['팀명'] == '롯데')]
# Out:
#     Unnamed: 0  순위    선수명  팀명     타율  경기   타석   타수  득점
# 0            0   1  페르난데스  두산  0.365  96  447  392  72
# 1            1   2    손아섭  롯데  0.350  90  395  343  67
# 6            6   7    오재일  두산  0.331  79  336  305  41
# 11          11  12     정훈  롯데  0.319  63  290  251  51
# 14          14  15    정수빈  두산  0.312  93  364  327  56
# 19          19  20    마차도  롯데  0.308  91  366  325  49
# 21          21  22    최주환  두산  0.301  94  385  345  46
# 22          22  23    박건우  두산  0.301  89  387  342  75
# 23          23  24    김재호  두산  0.298  75  299  258  34
# 26          26  27    이대호  롯데  0.293  91  388  345  42

# %%
df[df['팀명'] == '두산'].count()
# Out:
# Unnamed: 0    6
# 순위            6
# 선수명           6
# 팀명            6
# 타율            6
# 경기            6
# 타석            6
# 타수            6
# 득점            6
# dtype: int64

# %%
df[df['팀명'] == '롯데'].count()
# Out:
# Unnamed: 0    4
# 순위            4
# 선수명           4
# 팀명            4
# 타율            4
# 경기            4
# 타석            4
# 타수            4
# 득점            4
# dtype: int64

# %%
df[df['팀명'] == '키움'].count()
# Out:
# Unnamed: 0    2
# 순위            2
# 선수명           2
# 팀명            2
# 타율            2
# 경기            2
# 타석            2
# 타수            2
# 득점            2
# dtype: int64

# %%
df[df['팀명'] == 'NC'].count()
# Out:
# Unnamed: 0    4
# 순위            4
# 선수명           4
# 팀명            4
# 타율            4
# 경기            4
# 타석            4
# 타수            4
# 득점            4
# dtype: int64

# %%
df[df['팀명'] == 'KT'].count()
# Out:
# Unnamed: 0    6
# 순위            6
# 선수명           6
# 팀명            6
# 타율            6
# 경기            6
# 타석            6
# 타수            6
# 득점            6
# dtype: int64

# %%
df[df['팀명'] == '삼성'].count()
# Out:
# Unnamed: 0    3
# 순위            3
# 선수명           3
# 팀명            3
# 타율            3
# 경기            3
# 타석            3
# 타수            3
# 득점            3
# dtype: int64

# %%
df[df['팀명'] == 'KIA'].count()
# Out:
# Unnamed: 0    3
# 순위            3
# 선수명           3
# 팀명            3
# 타율            3
# 경기            3
# 타석            3
# 타수            3
# 득점            3
# dtype: int64

# %%
df[df['팀명'] == 'LG'].count()
# Out:
# Unnamed: 0    2
# 순위            2
# 선수명           2
# 팀명            2
# 타율            2
# 경기            2
# 타석            2
# 타수            2
# 득점            2
# dtype: int64

# %%
df['팀명'].unique()
# Out:
# array(['두산', '롯데', '키움', 'LG', 'KT', 'KIA', 'NC', '삼성'], dtype=object)

# %%
df['팀명'].value_counts()
# Out:
# KT     6
# 두산     6
# NC     4
# 롯데     4
# 삼성     3
# KIA    3
# LG     2
# 키움     2
# Name: 팀명, dtype: int64

# %%
df['타율 0.32 이상'] = (df['타율'] > 0.32)

# %%
df
# Out:
#     Unnamed: 0  순위    선수명   팀명     타율  경기   타석   타수  득점  타율 0.32 이상
# 0            0   1  페르난데스   두산  0.365  96  447  392  72        True
# 1            1   2    손아섭   롯데  0.350  90  395  343  67        True
# 2            2   3    이정후   키움  0.347  97  428  380  64        True
# 3            3   4    김현수   LG  0.346  97  427  384  70        True
# 4            4   5    로하스   KT  0.340  93  415  376  77        True
# 5            5   6    최형우  KIA  0.333  90  384  330  59        True
# 6            6   7    오재일   두산  0.331  79  336  305  41        True
# 7            7   7    이명기   NC  0.331  86  339  305  54        True
# 8            8   9    박민우   NC  0.325  74  310  277  48        True
# 9            9  10    나성범   NC  0.324  87  402  358  80        True
# 10          10  11    김상수   삼성  0.320  76  322  272  48       False
# 11          11  12     정훈   롯데  0.319  63  290  251  51       False
# 12          12  13    박해민   삼성  0.315  84  327  305  50       False
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  순위    선수명  팀명     타율  경기   타석   타수  득점  타율 0.32 이상
# 0           0   1  페르난데스  두산  0.365  96  447  392  72        True
# 1           1   2    손아섭  롯데  0.350  90  395  343  67        True
# 2           2   3    이정후  키움  0.347  97  428  380  64        True
# 3           3   4    김현수  LG  0.346  97  427  384  70        True
# 4           4   5    로하스  KT  0.340  93  415  376  77        True

# %%
df.tail()
# Out:
#     Unnamed: 0  순위  선수명   팀명     타율  경기   타석   타수  득점  타율 0.32 이상
# 25          25  26  황재균   KT  0.294  83  369  333  63       False
# 26          26  27  이대호   롯데  0.293  91  388  345  42       False
# 27          27  28  나지완  KIA  0.292  90  367  318  54       False
# 28          28  29  김하성   키움  0.292  96  439  370  84       False
# 29          29  30  장성우   KT  0.289  87  294  253  26       False

# %%
del df['타율 0.32 이상']

# %%
df
# Out:
#     Unnamed: 0  순위    선수명   팀명     타율  경기   타석   타수  득점
# 0            0   1  페르난데스   두산  0.365  96  447  392  72
# 1            1   2    손아섭   롯데  0.350  90  395  343  67
# 2            2   3    이정후   키움  0.347  97  428  380  64
# 3            3   4    김현수   LG  0.346  97  427  384  70
# 4            4   5    로하스   KT  0.340  93  415  376  77
# 5            5   6    최형우  KIA  0.333  90  384  330  59
# 6            6   7    오재일   두산  0.331  79  336  305  41
# 7            7   7    이명기   NC  0.331  86  339  305  54
# 8            8   9    박민우   NC  0.325  74  310  277  48
# 9            9  10    나성범   NC  0.324  87  402  358  80
# 10          10  11    김상수   삼성  0.320  76  322  272  48
# 11          11  12     정훈   롯데  0.319  63  290  251  51
# 12          12  13    박해민   삼성  0.315  84  327  305  50
# 13          13  14    강백호   KT  0.313  78  343  300  56
# 14          14  15    정수빈   두산  0.312  93  364  327  56
# 15          15  16    구자욱   삼성  0.311  72  312  273  39
# ...

# %%
df['타율'].plot()
# Out:
# <AxesSubplot:>
